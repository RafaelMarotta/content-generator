# %% [markdown]
# # Quiz video generator

# %% [markdown]
# ## Installing python dependencies

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## Generating a new quiz video

# %%
from quiz import full_video_quiz
# Example usage
questions_data = [
    {
        "title": "QUAL É O PLANETA MAIS PRÓXIMO DO SOL?",
        "title_speech": """<speak>Qual é o planeta mais próximo do sol?</speak>""",
        "answers": ["Mercúrio", "Vênus", "Marte", "Júpiter"],
        "answers_speech": [
            """<speak>Mercúrio</speak>""",
            """<speak>Vênus</speak>""",
            """<speak>Marte</speak>""",
            """<speak>Júpiter</speak>"""
        ],
        "correct_answer_index": 0,
        "correct_answer_speech": """<speak>E a resposta correta é: <break time="0.5s"/> Mercúrio! Muito bem se você acertou.</speak>""",
        "question_number": 1
    },
    {
        "title": "QUAL A CAPITAL DO BRASIL?",
        "title_speech": """<speak>Qual a capital do Brasil?</speak>""",
        "answers": ["São Paulo", "Rio de Janeiro", "Brasília", "Salvador"],
        "answers_speech": [
            """<speak>São Paulo</speak>""",
            """<speak>Rio de Janeiro</speak>""",
            """<speak>Brasília</speak>""",
            """<speak>Salvador</speak>"""
        ],
        "correct_answer_index": 2,
        "correct_answer_speech": """<speak>A resposta certa é: <break time="0.5s"/> Brasília!</speak>""",
        "question_number": 2
    },
    {
        "title": "QUEM PINTOU A MONA LISA?",
        "title_speech": """<speak>Quem pintou a Mona Lisa?</speak>""",
        "answers": ["Leonardo da Vinci", "Michelangelo", "Vincent van Gogh", "Pablo Picasso"],
        "answers_speech": [
            """<speak>Leonardo da Vinci</speak>""",
            """<speak>Michelangelo</speak>""",
            """<speak>Vincent van Gogh</speak>""",
            """<speak>Pablo Picasso</speak>"""
        ],
        "correct_answer_index": 0,
        "correct_answer_speech": """<speak>A resposta correta é: <break time="0.5s"/> Leonardo da Vinci!</speak>""",
        "question_number": 3
    }
]

full_video_quiz.generate_video(questions_data)
# Out:
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/1.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/2.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É O</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/3.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É O PLANETA</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/4.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É O PLANETA MAIS</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/5.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É O PLANETA MAIS PRÓXIMO</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/6.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É O PLANETA MAIS PRÓXIMO DO</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/7.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: None%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">1</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUAL É O PLANETA MAIS PRÓXIMO DO SOL?</div>
#
#             <!-- Options -->
#
#         </div>
#         <!-- Progress Bar -->
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated question image with effect: ../temp/1/question/img/8.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
# ...
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: 100%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">3</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUEM PINTOU A MONA LISA?</div>
#
#             <!-- Options -->
#
#             <div class="options">
#
#         <div class="option">
#             <div class="option-letter">A</div>
#             <div class="option-text">Leonardo da Vinci</div>
#         </div>
#
#         <div class="option">
#             <div class="option-letter">B</div>
#             <div class="option-text">Michelangelo</div>
#         </div>
#
#         <div class="option">
#             <div class="option-letter">C</div>
#             <div class="option-text">Vincent van Gogh</div>
#         </div>
#
#         <div class="option">
#             <div class="option-letter">D</div>
#             <div class="option-text">Pablo Picasso</div>
#         </div>
#
#             </div>
#
#         </div>
#         <!-- Progress Bar -->
#
#         <div class="progress-bar-container">
#             <div class="progress-bar"></div>
#         </div>
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated timer image with progress 100%: ../temp/3/timer/img/progress_100.png
# Template directory: /home/marotta/projects/youtube/quiz-generator/assets/template
# Template file: layout_template.html
# Generated HTML at: ../../temp/html/quiz_template_final.html
# Generated HTML Content:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>Quiz Image</title>
#     <!-- Include Local Fonts -->
#     <style>
#         /* @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Regular.ttf') format('truetype');
#             font-weight: 400;
#         }
#
#         @font-face {
#             font-family: 'Poppins';
#             src: url('file:///home/marotta/projects/youtube/quiz-generator/fonts/Poppins-Bold.ttf') format('truetype');
#             font-weight: 600;
#         } */
#
#
#         /* Reset and Base Styles */
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: #333;
#             display: table;
#             width: 1920px;
#             height: 1080px;
#             margin: 0;
#             padding: 0;
#             overflow: hidden;
#         }
#
#         .quiz-container {
#             background: #fff;
#             border-radius: 20px;
#             padding: 60px;
#             width: 90%;
#             max-width: 1000px;
#             text-align: center;
#             box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2);
#             position: relative;
#             display: table;
#             margin: 0 auto;
#             margin-top: 75px!important;
#         }
#
#         .question-number {
#             background-color: #ff6b6b;
#             color: white;
#             border-radius: 50%;
#             width: 80px;
#             height: 80px;
#             line-height: 80px;
#             font-size: 32px;
#             font-weight: 600;
#             text-align: center;
#             position: absolute;
#             top: -40px;
#             left: 50%;
#             transform: translateX(-50%);
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .content {
#             display: table-cell;
#             vertical-align: top;
#         }
#
#         .header {
#             font-size: 36px;
#             font-weight: 600;
#             margin-bottom: 40px;
#             color: #333;
#         }
#
#         .options {
#             display: block;
#             padding: 0 20px;
#             margin-top: 30px;
#             margin-bottom: 30px;
#         }
#
#         .option {
#             background: #f7f7f7;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-correct {
#             background-color: #d4edda;
#             border: 2px solid #28a745;
#             color: #333;
#             padding: 30px;
#             margin-top: 25px;
#             font-size: 24px;
#             border-radius: 15px;
#             display: table;
#             width: 100%;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
#         }
#
#         .option-letter {
#             background-color: #ff6b6b;
#             color: white;
#             width: 50px;
#             height: 50px;
#             line-height: 50px;
#             border-radius: 50%;
#             font-size: 20px;
#             font-weight: 600;
#             text-align: center;
#             display: table-cell;
#             vertical-align: middle;
#             box-shadow: 0 5px 15px rgba(0, 0, 0, 0.2);
#         }
#
#         .option-text {
#             display: table-cell;
#             vertical-align: middle;
#             text-align: left;
#             padding-left: 20px;
#         }
#
#         /* Progress Bar Styles */
#         .progress-bar-container {
#             width: 20px;
#             height: 100%;
#             background: #e0e0e0;
#             border-radius: 10px;
#             position: absolute;
#             right: -40px;
#             top: 0;
#             overflow: hidden;
#         }
#
#         .progress-bar {
#             width: 100%;
#             height: 100%;
#             background: linear-gradient(180deg, #28a745, #218838);
#             position: absolute;
#             bottom: 0;
#             left: 0;
#             border-radius: 10px;
#         }
#
#         /* Decorative Elements */
#         .background-pattern {
#             position: absolute;
#             top: -50px;
#             right: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#
#         .background-pattern-left {
#             position: absolute;
#             bottom: -50px;
#             left: -50px;
#             width: 300px;
#             height: 300px;
#             background: rgba(255, 255, 255, 0.05);
#             border-radius: 50%;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="quiz-container">
#         <div class="background-pattern"></div>
#         <div class="background-pattern-left"></div>
#         <div class="question-number">3</div>
#         <div class="content">
#             <!-- Question Title -->
#             <div class="header">QUEM PINTOU A MONA LISA?</div>
#
#             <!-- Options -->
#
#             <div class="options">
#
#         <div class="option-correct">
#             <div class="option-letter">A</div>
#             <div class="option-text">Leonardo da Vinci</div>
#         </div>
#
#         <div class="option">
#             <div class="option-letter">B</div>
#             <div class="option-text">Michelangelo</div>
#         </div>
#
#         <div class="option">
#             <div class="option-letter">C</div>
#             <div class="option-text">Vincent van Gogh</div>
#         </div>
#
#         <div class="option">
#             <div class="option-letter">D</div>
#             <div class="option-text">Pablo Picasso</div>
#         </div>
#
#             </div>
#
#         </div>
#         <!-- Progress Bar -->
#
#         <div class="progress-bar-container">
#             <div class="progress-bar"></div>
#         </div>
#
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Generated final image with correct answer: ../temp/3/correct/img/1.png
# Audio content written to ../temp/3/question/mp3/1.mp3
# Audio content written to ../temp/3/options/mp3/1.mp3
# Generated audio for answer 1: ../temp/3/options/mp3/1.mp3
# Audio content written to ../temp/3/options/mp3/2.mp3
# Generated audio for answer 2: ../temp/3/options/mp3/2.mp3
# Audio content written to ../temp/3/options/mp3/3.mp3
# Generated audio for answer 3: ../temp/3/options/mp3/3.mp3
# Audio content written to ../temp/3/options/mp3/4.mp3
# Generated audio for answer 4: ../temp/3/options/mp3/4.mp3
# <speak>A resposta correta é: <break time="0.5s"/> Leonardo da Vinci!</speak>
# Audio content written to ../temp/3/correct/mp3/1.mp3
# Moviepy - Building video ../temp/3/output/question_video.mp4.
# MoviePy - Writing audio in question_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ../temp/3/output/question_video.mp4
# Moviepy - Done !
# Moviepy - video ready ../temp/3/output/question_video.mp4
# Question video created: ../temp/3/output/question_video.mp4
# Moviepy - Building video ../temp/3/output/options_video.mp4.
# MoviePy - Writing audio in options_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ../temp/3/output/options_video.mp4
# Moviepy - Done !
# Moviepy - video ready ../temp/3/output/options_video.mp4
# Options video created: ../temp/3/output/options_video.mp4
# Images loaded in the following order:
# ../temp/3/timer/img/progress_0.png
# ../temp/3/timer/img/progress_10.png
# ../temp/3/timer/img/progress_20.png
# ../temp/3/timer/img/progress_30.png
# ../temp/3/timer/img/progress_40.png
# ../temp/3/timer/img/progress_50.png
# ../temp/3/timer/img/progress_60.png
# ../temp/3/timer/img/progress_70.png
# ../temp/3/timer/img/progress_80.png
# ../temp/3/timer/img/progress_90.png
# ../temp/3/timer/img/progress_100.png
# Moviepy - Building video ../temp/3/output/timer_video.mp4.
# MoviePy - Writing audio in timer_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ../temp/3/output/timer_video.mp4
# Moviepy - Done !
# Moviepy - video ready ../temp/3/output/timer_video.mp4
# Timer video created: ../temp/3/output/timer_video.mp4
# Moviepy - Building video ../temp/3/output/correct_answer_video.mp4.
# MoviePy - Writing audio in correct_answer_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ../temp/3/output/correct_answer_video.mp4
# Moviepy - Done !
# Moviepy - video ready ../temp/3/output/correct_answer_video.mp4
# Correct answer video created: ../temp/3/output/correct_answer_video.mp4
# No LADSPA plugins were found!
#
# Check your LADSPA_PATH environment variable.
# [mp3float @ 0x7503a0bf3340] Could not update timestamps for skipped samples.
# [mp3float @ 0x75031bcb9440] Could not update timestamps for skipped samples.
# [mp3float @ 0x7503a33f3800] Could not update timestamps for skipped samples.
# [mp3float @ 0x7502b763a1c0] Could not update timestamps for skipped samples.
# [mp4 @ 0x7503f00368c0] Timestamps are unset in a packet for stream 1. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# [mp4 @ 0x7503f00368c0] Encoder did not produce proper pts, making some up.
#
# No LADSPA plugins were found!
#
# Check your LADSPA_PATH environment variable.
# Final video created: ../temp/3/output/final_quiz_video_3.mp4
# Final quiz video for question 3 created at: ../temp/3/output/final_quiz_video_3.mp4
# All individual videos have been generated.
# [mp4 @ 0x7b14c0037b40] Timestamps are unset in a packet for stream 1. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# [mp4 @ 0x7b14c0037b40] Encoder did not produce proper pts, making some up.
# Final video created: ../output/final_quiz_video.mp4
# Final quiz video created at: ../output/final_quiz_video.mp4
# Video loaded: 55.21 seconds.
# Background music loaded: 100.44 seconds with volume set to 30.0%.
# Background music trimmed to match video duration of 55.21 seconds.
# Original audio found in video. Combining with background music.
# Exporting the final video to ../output/final_with_background.mp4...
# Moviepy - Building video ../output/final_with_background.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video ../output/final_with_background.mp4
# Moviepy - Done !
# Moviepy - video ready ../output/final_with_background.mp4
# Export completed successfully!

# %%
## Display the video

# %%
from IPython.display import Video

# Path to the video file
video_path = '../output/final_with_background.mp4'

# Display the video in the notebook
Video(video_path, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
